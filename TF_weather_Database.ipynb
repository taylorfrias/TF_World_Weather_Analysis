# %%
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 609

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in cities:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-03c900d9cc5f> in <module>
#       1 # Use the tuple() function to display the latitude and longitude combinations.
#       2 for coordinate in cities:
# ----> 3     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#       4           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/citipy/citipy.py in nearest_city(latitude, longitude)
#      35
#      36 def nearest_city(latitude, longitude):
# ---> 37     nearest_city_coordinate = _world_cities_kdtree.search_nn((latitude, longitude, ))
#      38     return WORLD_CITIES_DICT[nearest_city_coordinate[0].data]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in _wrapper(self, *args, **kwargs)
#     195                     dict(func_name=f.__name__, node=repr(self)))
#     196
# --> 197         return f(self, *args, **kwargs)
#     198
#     199     return _wrapper
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in search_nn(self, point, dist)
#     490         """
#     491
# --> 492         return next(iter(self.search_knn(point, 1, dist)), None)
#     493
#     494
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in search_knn(self, point, k, dist)
#     422         results = []
#     423
# --> 424         self._search_node(point, k, results, get_dist, itertools.count())
#     425
#     426         # We sort the final result by the distance in the tuple
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in _search_node(self, point, k, results, get_dist, counter)
#     433             return
#     434
# --> 435         nodeDist = get_dist(self)
#     436
#     437         # Add current node to the priority queue if it closer than
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in <lambda>(n)
#     416
#     417         if dist is None:
# --> 418             get_dist = lambda n: n.dist(point)
#     419         else:
#     420             get_dist = lambda n: dist(n.data, point)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in dist(self, point)
#     394         """
#     395         r = range(self.dimensions)
# --> 396         return sum([self.axis_dist(point, i) for i in r])
#     397
#     398
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in <listcomp>(.0)
#     394         """
#     395         r = range(self.dimensions)
# --> 396         return sum([self.axis_dist(point, i) for i in r])
#     397
#     398
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in axis_dist(self, point, axis)
#     385         the current Node and the given point
#     386         """
# --> 387         return math.pow(self.data[axis] - point[axis], 2)
#     388
#     389
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'

# %%
#Perform an API call with the OpenWeatherMap
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fcde0a0de712f8325b3087df358da1b7

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 28.51,
#   'pressure': 1013,
#   'humidity': 54,
#   'temp_min': 26.01,
#   'temp_max': 30.99},
#  'visibility': 16093,
#  'wind': {'speed': 11.41, 'deg': 300},
#  'snow': {},
#  'clouds': {'all': 90},
#  'dt': 1573604889,
#  'sys': {'type': 1,
#   'id': 3413,
#   'country': 'US',
#   'sunrise': 1573558264,
#   'sunset': 1573593949},
#  'timezone': -18000,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][["description"]]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,
                          "Description":city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 13 | aqtobe
# Processing Record 3 of Set 13 | mataura
# Processing Record 4 of Set 13 | turukhansk
# Processing Record 5 of Set 13 | bloemfontein
# Processing Record 6 of Set 13 | jamestown
# Processing Record 7 of Set 13 | atbasar
# Processing Record 8 of Set 13 | geraldton
# Processing Record 9 of Set 13 | ushuaia
# Processing Record 10 of Set 13 | tuatapere
# Processing Record 11 of Set 13 | kruisfontein
# Processing Record 12 of Set 13 | bengkulu
# City not found. Skipping...
# Processing Record 13 of Set 13 | hilo
# Processing Record 14 of Set 13 | hovd
# Processing Record 15 of Set 13 | east london
# Processing Record 16 of Set 13 | iqaluit
# Processing Record 17 of Set 13 | ribeira grande
# Processing Record 18 of Set 13 | pangnirtung
# Processing Record 19 of Set 13 | carnarvon
# Processing Record 20 of Set 13 | albany
# Processing Record 21 of Set 13 | rikitea
# Processing Record 22 of Set 13 | kapaa
# Processing Record 23 of Set 13 | pacific grove
# Processing Record 24 of Set 13 | chokurdakh
# Processing Record 25 of Set 13 | khatanga
# Processing Record 26 of Set 13 | taoudenni
# Processing Record 27 of Set 13 | sitka
# Processing Record 28 of Set 13 | eyl
# Processing Record 29 of Set 13 | roi et
# Processing Record 30 of Set 13 | saint-philippe
# Processing Record 31 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 13 | tsumeb
# Processing Record 33 of Set 13 | lorengau
# Processing Record 34 of Set 13 | naze
# Processing Record 35 of Set 13 | isangel
# Processing Record 36 of Set 13 | qaanaaq
# Processing Record 37 of Set 13 | husavik
# Processing Record 38 of Set 13 | llano de piedra
# Processing Record 39 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 40 of Set 13 | caravelas
# Processing Record 41 of Set 13 | lazaro cardenas
# Processing Record 42 of Set 13 | show low
# Processing Record 43 of Set 13 | port elizabeth
# Processing Record 44 of Set 13 | clyde river
# Processing Record 45 of Set 13 | yellowknife
# Processing Record 46 of Set 13 | ilulissat
# Processing Record 47 of Set 13 | punta arenas
# Processing Record 48 of Set 13 | thompson
# Processing Record 49 of Set 13 | maragogi
# Processing Record 50 of Set 13 | jiwani
# Processing Record 1 of Set 14 | businga
# Processing Record 2 of Set 14 | merauke
# Processing Record 3 of Set 14 | byron bay
# Processing Record 4 of Set 14 | ponta do sol
# Processing Record 5 of Set 14 | hermanus
# Processing Record 6 of Set 14 | beni
# Processing Record 7 of Set 14 | jackson
# Processing Record 8 of Set 14 | narsaq
# Processing Record 9 of Set 14 | cozumel
# City not found. Skipping...
# Processing Record 10 of Set 14 | vaini
# Processing Record 11 of Set 14 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 14 | cherskiy
# Processing Record 13 of Set 14 | lakes entrance
# Processing Record 14 of Set 14 | inongo
# Processing Record 15 of Set 14 | paamiut
# Processing Record 16 of Set 14 | lubango
# Processing Record 17 of Set 14 | barrow
# Processing Record 18 of Set 14 | xuchang
# Processing Record 19 of Set 14 | nikolskoye
# Processing Record 20 of Set 14 | kloulklubed
# Processing Record 21 of Set 14 | bredasdorp
# Processing Record 22 of Set 14 | cidreira
# Processing Record 23 of Set 14 | ewa beach
# Processing Record 24 of Set 14 | puerto suarez
# Processing Record 25 of Set 14 | tomatlan
# Processing Record 26 of Set 14 | dikson
# Processing Record 27 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 14 | sioux lookout
# Processing Record 29 of Set 14 | castro
# Processing Record 30 of Set 14 | turkistan
# City not found. Skipping...
# Processing Record 31 of Set 14 | sol-iletsk
# Processing Record 32 of Set 14 | kenora
# Processing Record 33 of Set 14 | severo-kurilsk
# Processing Record 34 of Set 14 | lebu
# Processing Record 35 of Set 14 | victoria
# Processing Record 36 of Set 14 | fukue
# Processing Record 37 of Set 14 | taltal
# Processing Record 38 of Set 14 | bluff
# Processing Record 39 of Set 14 | rocha
# Processing Record 40 of Set 14 | langxiang
# Processing Record 41 of Set 14 | tasiilaq
# Processing Record 42 of Set 14 | new norfolk
# Processing Record 43 of Set 14 | high level
# Processing Record 44 of Set 14 | ferme-neuve
# Processing Record 45 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 14 | tuktoyaktuk
# Processing Record 47 of Set 14 | klyuchi
# Processing Record 48 of Set 14 | hithadhoo
# Processing Record 49 of Set 14 | klaksvik
# Processing Record 50 of Set 14 | airai
# Processing Record 1 of Set 15 | taree
# Processing Record 2 of Set 15 | muli
# Processing Record 3 of Set 15 | kodiak
# Processing Record 4 of Set 15 | pula
# Processing Record 5 of Set 15 | dingle
# Processing Record 6 of Set 15 | tamworth
# Processing Record 7 of Set 15 | bubaque
# Processing Record 8 of Set 15 | dzhubga
# Processing Record 9 of Set 15 | port hedland
# Processing Record 10 of Set 15 | bambous virieux
# Processing Record 11 of Set 15 | owando
# Processing Record 12 of Set 15 | lompoc
# Processing Record 13 of Set 15 | kudahuvadhoo
# Processing Record 14 of Set 15 | chokwe
# City not found. Skipping...
# Processing Record 15 of Set 15 | deming
# Processing Record 16 of Set 15 | puerto ayora
# Processing Record 17 of Set 15 | buala
# Processing Record 18 of Set 15 | kawana waters
# City not found. Skipping...
# Processing Record 19 of Set 15 | marsh harbour
# Processing Record 20 of Set 15 | kingman
# Processing Record 21 of Set 15 | cabo san lucas
# Processing Record 22 of Set 15 | wana
# Processing Record 23 of Set 15 | cape town
# Processing Record 24 of Set 15 | tual
# Processing Record 25 of Set 15 | gurskoye
# City not found. Skipping...
# Processing Record 26 of Set 15 | paradwip
# City not found. Skipping...
# Processing Record 27 of Set 15 | champerico
# Processing Record 28 of Set 15 | pisco
# Processing Record 29 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 15 | olafsvik
# City not found. Skipping...
# Processing Record 31 of Set 15 | bronnoysund
# Processing Record 32 of Set 15 | sabha
# Processing Record 33 of Set 15 | port alfred
# Processing Record 34 of Set 15 | solnechnyy
# Processing Record 35 of Set 15 | longyearbyen
# Processing Record 36 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 15 | galesburg
# Processing Record 38 of Set 15 | kachug
# Processing Record 39 of Set 15 | tiksi
# Processing Record 40 of Set 15 | busselton
# Processing Record 41 of Set 15 | constitucion
# Processing Record 42 of Set 15 | attawapiskat
# City not found. Skipping...
# Processing Record 43 of Set 15 | xining
# Processing Record 44 of Set 15 | fortuna
# Processing Record 45 of Set 15 | matao
# Processing Record 46 of Set 15 | batemans bay
# Processing Record 47 of Set 15 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 15 | madison
# Processing Record 49 of Set 15 | hobart
# Processing Record 50 of Set 15 | kaitangata
# Processing Record 1 of Set 16 | upernavik
# Processing Record 2 of Set 16 | ahipara
# Processing Record 3 of Set 16 | nishihara
# Processing Record 4 of Set 16 | ulladulla
# Processing Record 5 of Set 16 | san carlos de bariloche
# Processing Record 6 of Set 16 | inirida
# Processing Record 7 of Set 16 | buchanan
# Processing Record 8 of Set 16 | mar del plata
# Processing Record 9 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 10 of Set 16 | provideniya
# Processing Record 11 of Set 16 | mogwase
# Processing Record 12 of Set 16 | stavern
# Processing Record 13 of Set 16 | srednekolymsk
# Processing Record 14 of Set 16 | akyab
# City not found. Skipping...
# Processing Record 15 of Set 16 | el faiyum
# City not found. Skipping...
# Processing Record 16 of Set 16 | codrington
# Processing Record 17 of Set 16 | moratuwa
# Processing Record 18 of Set 16 | torbay
# Processing Record 19 of Set 16 | norilsk
# Processing Record 20 of Set 16 | grand gaube
# Processing Record 21 of Set 16 | staunton
# Processing Record 22 of Set 16 | baherden
# Processing Record 23 of Set 16 | kubachi
# Processing Record 24 of Set 16 | banda aceh
# Processing Record 25 of Set 16 | baykit
# Processing Record 26 of Set 16 | barra do garcas
# Processing Record 27 of Set 16 | kapit
# Processing Record 28 of Set 16 | cimislia
# Processing Record 29 of Set 16 | chumikan
# Processing Record 30 of Set 16 | goderich
# Processing Record 31 of Set 16 | yugorsk
# Processing Record 32 of Set 16 | houma
# Processing Record 33 of Set 16 | la plata
# Processing Record 34 of Set 16 | tymovskoye
# Processing Record 35 of Set 16 | luba
# Processing Record 36 of Set 16 | mayo
# Processing Record 37 of Set 16 | matagami
# Processing Record 38 of Set 16 | sao joao da barra
# Processing Record 39 of Set 16 | aykhal
# Processing Record 40 of Set 16 | fare
# Processing Record 41 of Set 16 | sao filipe
# Processing Record 42 of Set 16 | jieshi
# Processing Record 43 of Set 16 | sovkhoznyy
# Processing Record 44 of Set 16 | saint-augustin
# Processing Record 45 of Set 16 | macas
# Processing Record 46 of Set 16 | arraial do cabo
# Processing Record 47 of Set 16 | ancud
# Processing Record 48 of Set 16 | bani walid
# Processing Record 49 of Set 16 | talnakh
# Processing Record 50 of Set 16 | faanui
# Processing Record 1 of Set 17 | quang ngai
# Processing Record 2 of Set 17 | pocone
# Processing Record 3 of Set 17 | les cayes
# Processing Record 4 of Set 17 | marietta
# Processing Record 5 of Set 17 | butaritari
# Processing Record 6 of Set 17 | atuona
# Processing Record 7 of Set 17 | sakakah
# City not found. Skipping...
# Processing Record 8 of Set 17 | sartell
# Processing Record 9 of Set 17 | sumbawa
# City not found. Skipping...
# Processing Record 10 of Set 17 | kavieng
# Processing Record 11 of Set 17 | ostrovnoy
# Processing Record 12 of Set 17 | bitung
# Processing Record 13 of Set 17 | havre-saint-pierre
# Processing Record 14 of Set 17 | vastervik
# City not found. Skipping...
# Processing Record 15 of Set 17 | kimbe
# Processing Record 16 of Set 17 | chabahar
# Processing Record 17 of Set 17 | katsuura
# Processing Record 18 of Set 17 | arman
# Processing Record 19 of Set 17 | ternate
# Processing Record 20 of Set 17 | muros
# Processing Record 21 of Set 17 | alice springs
# Processing Record 22 of Set 17 | bethel
# Processing Record 23 of Set 17 | nelson bay
# Processing Record 24 of Set 17 | hamilton
# Processing Record 25 of Set 17 | barentsburg
# City not found. Skipping...
# Processing Record 26 of Set 17 | rincon
# Processing Record 27 of Set 17 | mahebourg
# Processing Record 28 of Set 17 | farafangana
# Processing Record 29 of Set 17 | aklavik
# Processing Record 30 of Set 17 | vila franca do campo
# Processing Record 31 of Set 17 | plaisance-du-touch
# Processing Record 32 of Set 17 | chapais
# Processing Record 33 of Set 17 | bodden town
# Processing Record 34 of Set 17 | vila
# Processing Record 35 of Set 17 | linjiang
# Processing Record 36 of Set 17 | yar-sale
# Processing Record 37 of Set 17 | saint george
# Processing Record 38 of Set 17 | florianopolis
# Processing Record 39 of Set 17 | mpulungu
# Processing Record 40 of Set 17 | coahuayana
# Processing Record 41 of Set 17 | esperance
# Processing Record 42 of Set 17 | sehithwa
# Processing Record 43 of Set 17 | hirara
# Processing Record 44 of Set 17 | moba
# Processing Record 45 of Set 17 | liwale
# Processing Record 46 of Set 17 | puksoozero
# Processing Record 47 of Set 17 | cayenne
# Processing Record 48 of Set 17 | touros
# Processing Record 49 of Set 17 | guajara-mirim
# City not found. Skipping...
# Processing Record 50 of Set 17 | pampierstad
# Processing Record 1 of Set 18 | surovikino
# Processing Record 2 of Set 18 | karratha
# Processing Record 3 of Set 18 | acatic
# Processing Record 4 of Set 18 | san quintin
# Processing Record 5 of Set 18 | newtonmore
# Processing Record 6 of Set 18 | mackay
# Processing Record 7 of Set 18 | okhotsk
# Processing Record 8 of Set 18 | ballina
# Processing Record 9 of Set 18 | avarua
# Processing Record 10 of Set 18 | aswan
# Processing Record 11 of Set 18 | aguimes
# Processing Record 12 of Set 18 | weihe
# Processing Record 13 of Set 18 | morondava
# Processing Record 14 of Set 18 | norman wells
# Processing Record 15 of Set 18 | naryan-mar
# Processing Record 16 of Set 18 | shaki
# Processing Record 17 of Set 18 | ucluelet
# Processing Record 18 of Set 18 | nemuro
# Processing Record 19 of Set 18 | beloha
# Processing Record 20 of Set 18 | las lomas
# Processing Record 21 of Set 18 | saint-joseph
# Processing Record 22 of Set 18 | katherine
# Processing Record 23 of Set 18 | broken hill
# Processing Record 24 of Set 18 | erenhot
# Processing Record 25 of Set 18 | skiros
# City not found. Skipping...
# Processing Record 26 of Set 18 | arlit
# Processing Record 27 of Set 18 | nador
# Processing Record 28 of Set 18 | changde
# Processing Record 29 of Set 18 | svetlyy
# City not found. Skipping...
# Processing Record 30 of Set 18 | pyapon
# Processing Record 31 of Set 18 | nanortalik
# Processing Record 32 of Set 18 | tabiauea
# City not found. Skipping...
# Processing Record 33 of Set 18 | emirdag
# Processing Record 34 of Set 18 | college
# Processing Record 35 of Set 18 | pevek
# Processing Record 36 of Set 18 | paita
# Processing Record 37 of Set 18 | ha tinh
# Processing Record 38 of Set 18 | kazalinsk
# City not found. Skipping...
# Processing Record 39 of Set 18 | catalina
# Processing Record 40 of Set 18 | iskateley
# Processing Record 41 of Set 18 | alofi
# Processing Record 42 of Set 18 | atocha
# Processing Record 43 of Set 18 | kalga
# Processing Record 44 of Set 18 | vostok
# Processing Record 45 of Set 18 | gusino
# Processing Record 46 of Set 18 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 18 | kamenka
# Processing Record 48 of Set 18 | hongjiang
# Processing Record 49 of Set 18 | coquimbo
# Processing Record 50 of Set 18 | urusha
# Processing Record 1 of Set 19 | santa fe
# Processing Record 2 of Set 19 | mata
# Processing Record 3 of Set 19 | talara
# Processing Record 4 of Set 19 | neverkino
# Processing Record 5 of Set 19 | garowe
# Processing Record 6 of Set 19 | boquira
# Processing Record 7 of Set 19 | lannion
# Processing Record 8 of Set 19 | gajraula
# Processing Record 9 of Set 19 | san pedro de ycuamandiyu
# Processing Record 10 of Set 19 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 19 | camacha
# Processing Record 12 of Set 19 | siocon
# Processing Record 13 of Set 19 | hudiksvall
# Processing Record 14 of Set 19 | lyubech
# Processing Record 15 of Set 19 | buraydah
# Processing Record 16 of Set 19 | rawson
# Processing Record 17 of Set 19 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 19 | souillac
# Processing Record 19 of Set 19 | mana
# Processing Record 20 of Set 19 | mangan
# Processing Record 21 of Set 19 | seabra
# Processing Record 22 of Set 19 | longlac
# City not found. Skipping...
# Processing Record 23 of Set 19 | loksa
# Processing Record 24 of Set 19 | khandyga
# Processing Record 25 of Set 19 | raudeberg
# Processing Record 26 of Set 19 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 19 | hay river
# Processing Record 28 of Set 19 | saldanha
# Processing Record 29 of Set 19 | roald
# Processing Record 30 of Set 19 | oltu
# Processing Record 31 of Set 19 | fairbanks
# Processing Record 32 of Set 19 | luderitz
# Processing Record 33 of Set 19 | mount isa
# Processing Record 34 of Set 19 | tripoli
# Processing Record 35 of Set 19 | valparaiso
# Processing Record 36 of Set 19 | hofn
# Processing Record 37 of Set 19 | hervey bay
# Processing Record 38 of Set 19 | tunghsiao
# City not found. Skipping...
# Processing Record 39 of Set 19 | aripuana
# Processing Record 40 of Set 19 | mossendjo
# Processing Record 41 of Set 19 | vao
# Processing Record 42 of Set 19 | jiayuguan
# Processing Record 43 of Set 19 | mocuba
# Processing Record 44 of Set 19 | milazzo
# Processing Record 45 of Set 19 | tessalit
# Processing Record 46 of Set 19 | oranjestad
# Processing Record 47 of Set 19 | esso
# Processing Record 48 of Set 19 | greenville
# Processing Record 49 of Set 19 | aflu
# City not found. Skipping...
# Processing Record 50 of Set 19 | mezen
# Processing Record 1 of Set 20 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 20 | verkhoyansk
# Processing Record 3 of Set 20 | korla
# City not found. Skipping...
# Processing Record 4 of Set 20 | lagoa
# Processing Record 5 of Set 20 | mount gambier
# Processing Record 6 of Set 20 | te anau
# Processing Record 7 of Set 20 | vila do maio
# Processing Record 8 of Set 20 | songling
# Processing Record 9 of Set 20 | aksu
# Processing Record 10 of Set 20 | gazojak
# Processing Record 11 of Set 20 | luanda
# Processing Record 12 of Set 20 | half moon bay
# Processing Record 13 of Set 20 | qasigiannguit
# Processing Record 14 of Set 20 | chuy
# Processing Record 15 of Set 20 | kouroussa
# Processing Record 16 of Set 20 | houston
# Processing Record 17 of Set 20 | punta ocote
# Processing Record 18 of Set 20 | lata
# Processing Record 19 of Set 20 | ugoofaaru
# Processing Record 20 of Set 20 | oistins
# Processing Record 21 of Set 20 | georgetown
# Processing Record 22 of Set 20 | kathu
# Processing Record 23 of Set 20 | kabompo
# Processing Record 24 of Set 20 | sangmelima
# Processing Record 25 of Set 20 | bathsheba
# Processing Record 26 of Set 20 | galesong
# Processing Record 27 of Set 20 | carballo
# Processing Record 28 of Set 20 | bria
# Processing Record 29 of Set 20 | saint-louis
# Processing Record 30 of Set 20 | salina
# Processing Record 31 of Set 20 | dunedin
# Processing Record 32 of Set 20 | torring
# Processing Record 33 of Set 20 | de-kastri
# Processing Record 34 of Set 20 | san cristobal
# Processing Record 35 of Set 20 | port macquarie
# Processing Record 36 of Set 20 | bulgan
# Processing Record 37 of Set 20 | vanimo
# Processing Record 38 of Set 20 | konotop
# Processing Record 39 of Set 20 | urumqi
# City not found. Skipping...
# Processing Record 40 of Set 20 | komsomolskiy
# Processing Record 41 of Set 20 | hebi
# Processing Record 42 of Set 20 | bababe
# City not found. Skipping...
# Processing Record 43 of Set 20 | bam
# Processing Record 44 of Set 20 | balkhash
# Processing Record 45 of Set 20 | adrar
# Processing Record 46 of Set 20 | anloga
# Processing Record 47 of Set 20 | hoopstad
# Processing Record 48 of Set 20 | ciudad bolivar
# Processing Record 49 of Set 20 | launceston
# Processing Record 50 of Set 20 | dhar
# Processing Record 1 of Set 21 | ahuimanu
# Processing Record 2 of Set 21 | carutapera
# Processing Record 3 of Set 21 | honiara
# Processing Record 4 of Set 21 | ituni
# City not found. Skipping...
# Processing Record 5 of Set 21 | curup
# Processing Record 6 of Set 21 | pelym
# Processing Record 7 of Set 21 | barawe
# City not found. Skipping...
# Processing Record 8 of Set 21 | namibe
# Processing Record 9 of Set 21 | horsham
# Processing Record 10 of Set 21 | sobolevo
# Processing Record 11 of Set 21 | winslow
# Processing Record 12 of Set 21 | bossangoa
# Processing Record 13 of Set 21 | cary
# Processing Record 14 of Set 21 | cumaribo
# City not found. Skipping...
# Processing Record 15 of Set 21 | saskylakh
# Processing Record 16 of Set 21 | kahului
# Processing Record 17 of Set 21 | polyarnyy
# Processing Record 18 of Set 21 | ikorodu
# Processing Record 19 of Set 21 | ponta delgada
# Processing Record 20 of Set 21 | bardiyah
# City not found. Skipping...
# Processing Record 21 of Set 21 | mahon
# Processing Record 22 of Set 21 | gizo
# Processing Record 23 of Set 21 | cuiluan
# Processing Record 24 of Set 21 | kamenskoye
# City not found. Skipping...
# Processing Record 25 of Set 21 | narasannapeta
# Processing Record 26 of Set 21 | mehamn
# Processing Record 27 of Set 21 | sabalgarh
# Processing Record 28 of Set 21 | broome
# Processing Record 29 of Set 21 | santa rosa
# Processing Record 30 of Set 21 | lakatoro
# Processing Record 31 of Set 21 | warqla
# City not found. Skipping...
# Processing Record 32 of Set 21 | bur gabo
# City not found. Skipping...
# Processing Record 33 of Set 21 | manicore
# Processing Record 34 of Set 21 | pedernales
# Processing Record 35 of Set 21 | kirgiz-miyaki
# Processing Record 36 of Set 21 | morros
# Processing Record 37 of Set 21 | okakarara
# Processing Record 38 of Set 21 | guerrero negro
# Processing Record 39 of Set 21 | hobyo
# Processing Record 40 of Set 21 | panzhihua
# Processing Record 41 of Set 21 | samalaeulu
# City not found. Skipping...
# Processing Record 42 of Set 21 | mutoko
# Processing Record 43 of Set 21 | saint quentin
# City not found. Skipping...
# Processing Record 44 of Set 21 | tupik
# Processing Record 45 of Set 21 | agadez
# Processing Record 46 of Set 21 | leningradskiy
# Processing Record 47 of Set 21 | camana
# City not found. Skipping...
# Processing Record 48 of Set 21 | dolgorukovo
# Processing Record 49 of Set 21 | kieta
# Processing Record 50 of Set 21 | shizunai
# Processing Record 1 of Set 22 | zhigansk
# Processing Record 2 of Set 22 | dinghai
# Processing Record 3 of Set 22 | nome
# Processing Record 4 of Set 22 | evensk
# Processing Record 5 of Set 22 | neuquen
# Processing Record 6 of Set 22 | agen
# Processing Record 7 of Set 22 | abiy adi
# City not found. Skipping...
# Processing Record 8 of Set 22 | russell
# Processing Record 9 of Set 22 | bambanglipuro
# Processing Record 10 of Set 22 | lumeje
# Processing Record 11 of Set 22 | qingan
# City not found. Skipping...
# Processing Record 12 of Set 22 | kavaratti
# Processing Record 13 of Set 22 | vardo
# Processing Record 14 of Set 22 | termoli
# Processing Record 15 of Set 22 | conroe
# Processing Record 16 of Set 22 | agadir
# Processing Record 17 of Set 22 | otradnoye
# Processing Record 18 of Set 22 | virginia beach
# Processing Record 19 of Set 22 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 20 of Set 22 | tumannyy
# City not found. Skipping...
# Processing Record 21 of Set 22 | port augusta
# Processing Record 22 of Set 22 | praia
# Processing Record 23 of Set 22 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 22 | tongchuan
# Processing Record 25 of Set 22 | khormuj
# City not found. Skipping...
# Processing Record 26 of Set 22 | batie
# Processing Record 27 of Set 22 | matane
# Processing Record 28 of Set 22 | juba
# Processing Record 29 of Set 22 | kalmunai
# Processing Record 30 of Set 22 | rio gallegos
# Processing Record 31 of Set 22 | boddam
# Processing Record 32 of Set 22 | ambodifototra
# City not found. Skipping...
# Processing Record 33 of Set 22 | shimoda
# Processing Record 34 of Set 22 | nizhneyansk
# City not found. Skipping...
# Processing Record 35 of Set 22 | yanam
# Processing Record 36 of Set 22 | saint-pierre
# Processing Record 37 of Set 22 | bonavista
# Processing Record 38 of Set 22 | barra do bugres
# Processing Record 39 of Set 22 | awbari
# Processing Record 40 of Set 22 | baghdad
# Processing Record 41 of Set 22 | labuhan
# Processing Record 42 of Set 22 | ipueiras
# Processing Record 43 of Set 22 | rafaela
# Processing Record 44 of Set 22 | westport
# Processing Record 45 of Set 22 | deputatskiy
# Processing Record 46 of Set 22 | tankhoy
# Processing Record 47 of Set 22 | rungata
# City not found. Skipping...
# Processing Record 48 of Set 22 | yerbogachen
# Processing Record 49 of Set 22 | pimenta bueno
# Processing Record 50 of Set 22 | vila velha
# Processing Record 1 of Set 23 | port-gentil
# Processing Record 2 of Set 23 | brainerd
# Processing Record 3 of Set 23 | veliki crljeni
# Processing Record 4 of Set 23 | pinawa
# Processing Record 5 of Set 23 | atar
# Processing Record 6 of Set 23 | yiyang
# Processing Record 7 of Set 23 | conde
# Processing Record 8 of Set 23 | manaure
# Processing Record 9 of Set 23 | batticaloa
# Processing Record 10 of Set 23 | sanandaj
# Processing Record 11 of Set 23 | tautira
# Processing Record 12 of Set 23 | ixtapa
# Processing Record 13 of Set 23 | galdar
# Processing Record 14 of Set 23 | shenandoah
# Processing Record 15 of Set 23 | port lincoln
# Processing Record 16 of Set 23 | colomi
# Processing Record 17 of Set 23 | le pont-de-claix
# Processing Record 18 of Set 23 | antalaha
# Processing Record 19 of Set 23 | itaituba
# Processing Record 20 of Set 23 | soderhamn
# Processing Record 21 of Set 23 | hallingby
# City not found. Skipping...
# Processing Record 22 of Set 23 | yumen
# Processing Record 23 of Set 23 | tunxi
# City not found. Skipping...
# Processing Record 24 of Set 23 | hirado
# Processing Record 25 of Set 23 | puerto rico
# Processing Record 26 of Set 23 | gerash
# Processing Record 27 of Set 23 | bar harbor
# Processing Record 28 of Set 23 | balimo
# City not found. Skipping...
# Processing Record 29 of Set 23 | portland
# Processing Record 30 of Set 23 | mahaena
# City not found. Skipping...
# Processing Record 31 of Set 23 | whitehorse
# Processing Record 32 of Set 23 | nyurba
# Processing Record 33 of Set 23 | higuey
# City not found. Skipping...
# Processing Record 34 of Set 23 | helong
# Processing Record 35 of Set 23 | santiago de las vegas
# Processing Record 36 of Set 23 | derzhavinsk
# Processing Record 37 of Set 23 | namatanai
# Processing Record 38 of Set 23 | kutum
# Processing Record 39 of Set 23 | manitowoc
# Processing Record 40 of Set 23 | hasaki
# Processing Record 41 of Set 23 | salalah
# Processing Record 42 of Set 23 | campana
# Processing Record 43 of Set 23 | halifax
# Processing Record 44 of Set 23 | toftir
# City not found. Skipping...
# Processing Record 45 of Set 23 | taft
# Processing Record 46 of Set 23 | henties bay
# Processing Record 47 of Set 23 | kenai
# Processing Record 48 of Set 23 | hambantota
# Processing Record 49 of Set 23 | tilichiki
# Processing Record 50 of Set 23 | tianpeng
# Processing Record 1 of Set 24 | bedele
# Processing Record 2 of Set 24 | victor harbor
# Processing Record 3 of Set 24 | saint-leu
# Processing Record 4 of Set 24 | nagato
# Processing Record 5 of Set 24 | padang
# Processing Record 6 of Set 24 | stornoway
# City not found. Skipping...
# Processing Record 7 of Set 24 | san policarpo
# Processing Record 8 of Set 24 | hualmay
# Processing Record 9 of Set 24 | ulaangom
# Processing Record 10 of Set 24 | oda
# Processing Record 11 of Set 24 | la rioja
# Processing Record 12 of Set 24 | marsabit
# Processing Record 13 of Set 24 | kathmandu
# Processing Record 14 of Set 24 | micheweni
# Processing Record 15 of Set 24 | valdez
# Processing Record 16 of Set 24 | atambua
# Processing Record 17 of Set 24 | weiser
# Processing Record 18 of Set 24 | lavrentiya
# Processing Record 19 of Set 24 | miguel calmon
# Processing Record 20 of Set 24 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 24 | petropavlovsk-kamchatskiy
# Processing Record 22 of Set 24 | tias
# Processing Record 23 of Set 24 | quartucciu
# Processing Record 24 of Set 24 | abha
# Processing Record 25 of Set 24 | severnyy
# City not found. Skipping...
# Processing Record 26 of Set 24 | ganzhou
# Processing Record 27 of Set 24 | tazovskiy
# Processing Record 28 of Set 24 | north platte
# Processing Record 29 of Set 24 | grindavik
# Processing Record 30 of Set 24 | wanning
# Processing Record 31 of Set 24 | malanje
# Processing Record 32 of Set 24 | warmbad
# Processing Record 33 of Set 24 | dwarka
# Processing Record 34 of Set 24 | porto velho
# Processing Record 35 of Set 24 | svetlaya
# Processing Record 36 of Set 24 | kyren
# Processing Record 37 of Set 24 | khilok
# Processing Record 38 of Set 24 | kashi
# City not found. Skipping...
# Processing Record 39 of Set 24 | chicama
# Processing Record 40 of Set 24 | myitkyina
# Processing Record 41 of Set 24 | taburao
# City not found. Skipping...
# Processing Record 42 of Set 24 | yenagoa
# Processing Record 43 of Set 24 | hami
# Processing Record 44 of Set 24 | denpasar
# Processing Record 45 of Set 24 | egvekinot
# Processing Record 46 of Set 24 | emba
# Processing Record 47 of Set 24 | tura
# Processing Record 48 of Set 24 | viedma
# Processing Record 49 of Set 24 | san andres
# Processing Record 50 of Set 24 | puerto escondido
# Processing Record 1 of Set 25 | saveh
# Processing Record 2 of Set 25 | barpeta
# Processing Record 3 of Set 25 | jiazi
# Processing Record 4 of Set 25 | boende
# Processing Record 5 of Set 25 | cockburn town
# Processing Record 6 of Set 25 | meyungs
# City not found. Skipping...
# Processing Record 7 of Set 25 | moree
# Processing Record 8 of Set 25 | onega
# Processing Record 9 of Set 25 | cururupu
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Aqtobe  50.28   57.21     35.60        69          75        4.47
# 1       Mataura -46.19  168.86     62.01        62         100        5.99
# 2    Turukhansk  65.80   87.96      2.93        96         100        5.97
# 3  Bloemfontein -29.12   26.22     55.40        93           0        4.70
# 4     Jamestown -33.21  138.60     59.90        48          57       12.80
# 5       Atbasar  51.81   68.36     21.65        90          87       10.76
# 6     Geraldton  49.72  -86.95     -0.41        77          75        4.70
# 7       Ushuaia -54.81  -68.31     51.80        66          75       10.29
# 8     Tuatapere -46.13  167.69     62.01        62         100        5.99
# 9  Kruisfontein -34.00   24.73     60.22        90          95        9.48
#
#   Country                 Date  \
# 0      KZ  2019-11-13 00:39:37
# 1      NZ  2019-11-13 00:42:46
# 2      RU  2019-11-13 00:42:47
# 3      ZA  2019-11-13 00:39:38
# 4      AU  2019-11-13 00:42:47
# 5      KZ  2019-11-13 00:39:38
# 6      CA  2019-11-13 00:42:47
# 7      AR  2019-11-13 00:42:48
# 8      NZ  2019-11-13 00:42:48
# 9      ZA  2019-11-13 00:42:48
#
#                                          Description
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...
# 1  [{'id': 804, 'main': 'Clouds', 'description': ...
# 2  [{'id': 600, 'main': 'Snow', 'description': 'l...
# 3  [{'id': 800, 'main': 'Clear', 'description': '...
# 4  [{'id': 803, 'main': 'Clouds', 'description': ...
# 5  [{'id': 804, 'main': 'Clouds', 'description': ...
# 6  [{'id': 803, 'main': 'Clouds', 'description': ...
# 7  [{'id': 803, 'main': 'Clouds', 'description': ...
# 8  [{'id': 501, 'main': 'Rain', 'description': 'm...
# 9  [{'id': 500, 'main': 'Rain', 'description': 'l...

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_vacation.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
