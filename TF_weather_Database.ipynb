# %%
import random
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
# Import the dependencies.
import pandas as pd
import gmaps
import requests
# Import the API key.
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 604

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in cities:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-03c900d9cc5f> in <module>
#       1 # Use the tuple() function to display the latitude and longitude combinations.
#       2 for coordinate in cities:
# ----> 3     print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
#       4           citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/citipy/citipy.py in nearest_city(latitude, longitude)
#      35
#      36 def nearest_city(latitude, longitude):
# ---> 37     nearest_city_coordinate = _world_cities_kdtree.search_nn((latitude, longitude, ))
#      38     return WORLD_CITIES_DICT[nearest_city_coordinate[0].data]
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in _wrapper(self, *args, **kwargs)
#     195                     dict(func_name=f.__name__, node=repr(self)))
#     196
# --> 197         return f(self, *args, **kwargs)
#     198
#     199     return _wrapper
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in search_nn(self, point, dist)
#     490         """
#     491
# --> 492         return next(iter(self.search_knn(point, 1, dist)), None)
#     493
#     494
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in search_knn(self, point, k, dist)
#     422         results = []
#     423
# --> 424         self._search_node(point, k, results, get_dist, itertools.count())
#     425
#     426         # We sort the final result by the distance in the tuple
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in _search_node(self, point, k, results, get_dist, counter)
#     433             return
#     434
# --> 435         nodeDist = get_dist(self)
#     436
#     437         # Add current node to the priority queue if it closer than
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in <lambda>(n)
#     416
#     417         if dist is None:
# --> 418             get_dist = lambda n: n.dist(point)
#     419         else:
#     420             get_dist = lambda n: dist(n.data, point)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in dist(self, point)
#     394         """
#     395         r = range(self.dimensions)
# --> 396         return sum([self.axis_dist(point, i) for i in r])
#     397
#     398
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in <listcomp>(.0)
#     394         """
#     395         r = range(self.dimensions)
# --> 396         return sum([self.axis_dist(point, i) for i in r])
#     397
#     398
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/kdtree.py in axis_dist(self, point, axis)
#     385         the current Node and the given point
#     386         """
# --> 387         return math.pow(self.data[axis] - point[axis], 2)
#     388
#     389
#
# TypeError: unsupported operand type(s) for -: 'float' and 'str'

# %%
#Perform an API call with the OpenWeatherMap
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=fcde0a0de712f8325b3087df358da1b7

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
    
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date,})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | constitucion
# Processing Record 2 of Set 13 | hilo
# Processing Record 3 of Set 13 | mataura
# Processing Record 4 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 5 of Set 13 | ribeira grande
# Processing Record 6 of Set 13 | busselton
# Processing Record 7 of Set 13 | komsomolskiy
# Processing Record 8 of Set 13 | cape town
# Processing Record 9 of Set 13 | kapaa
# Processing Record 10 of Set 13 | puerto ayora
# Processing Record 11 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 12 of Set 13 | cayenne
# Processing Record 13 of Set 13 | albany
# Processing Record 14 of Set 13 | brae
# Processing Record 15 of Set 13 | rikitea
# Processing Record 16 of Set 13 | meulaboh
# Processing Record 17 of Set 13 | katsuura
# Processing Record 18 of Set 13 | barrow
# Processing Record 19 of Set 13 | beira
# Processing Record 20 of Set 13 | batemans bay
# Processing Record 21 of Set 13 | kodiak
# Processing Record 22 of Set 13 | sisimiut
# Processing Record 23 of Set 13 | bredasdorp
# Processing Record 24 of Set 13 | camopi
# Processing Record 25 of Set 13 | ourossogui
# Processing Record 26 of Set 13 | yanam
# Processing Record 27 of Set 13 | khandbari
# Processing Record 28 of Set 13 | talnakh
# Processing Record 29 of Set 13 | castro
# Processing Record 30 of Set 13 | mahajanga
# Processing Record 31 of Set 13 | punta arenas
# Processing Record 32 of Set 13 | aksu
# Processing Record 33 of Set 13 | hualmay
# Processing Record 34 of Set 13 | jamestown
# Processing Record 35 of Set 13 | lukovetskiy
# Processing Record 36 of Set 13 | bambous virieux
# Processing Record 37 of Set 13 | bengkulu
# City not found. Skipping...
# Processing Record 38 of Set 13 | barentsburg
# City not found. Skipping...
# Processing Record 39 of Set 13 | upernavik
# Processing Record 40 of Set 13 | georgetown
# Processing Record 41 of Set 13 | hobart
# Processing Record 42 of Set 13 | ushuaia
# Processing Record 43 of Set 13 | yellowknife
# Processing Record 44 of Set 13 | lompoc
# Processing Record 45 of Set 13 | nanortalik
# Processing Record 46 of Set 13 | formosa
# Processing Record 47 of Set 13 | tessalit
# Processing Record 48 of Set 13 | wasilla
# Processing Record 49 of Set 13 | babylon
# Processing Record 50 of Set 13 | vardo
# Processing Record 1 of Set 14 | cherskiy
# Processing Record 2 of Set 14 | kudahuvadhoo
# Processing Record 3 of Set 14 | flin flon
# Processing Record 4 of Set 14 | iqaluit
# Processing Record 5 of Set 14 | iwanai
# Processing Record 6 of Set 14 | chunskiy
# Processing Record 7 of Set 14 | ixtapa
# Processing Record 8 of Set 14 | ponta do sol
# Processing Record 9 of Set 14 | qaanaaq
# Processing Record 10 of Set 14 | kansas city
# Processing Record 11 of Set 14 | cam ranh
# Processing Record 12 of Set 14 | berezovyy
# Processing Record 13 of Set 14 | tuktoyaktuk
# Processing Record 14 of Set 14 | basqal
# Processing Record 15 of Set 14 | panlaitan
# Processing Record 16 of Set 14 | taoudenni
# Processing Record 17 of Set 14 | thompson
# Processing Record 18 of Set 14 | nikolskoye
# Processing Record 19 of Set 14 | vaini
# Processing Record 20 of Set 14 | achutupo
# City not found. Skipping...
# Processing Record 21 of Set 14 | san patricio
# Processing Record 22 of Set 14 | kajaani
# Processing Record 23 of Set 14 | chokurdakh
# Processing Record 24 of Set 14 | mahibadhoo
# Processing Record 25 of Set 14 | kuah
# City not found. Skipping...
# Processing Record 26 of Set 14 | bonfim
# Processing Record 27 of Set 14 | avarua
# Processing Record 28 of Set 14 | kabalo
# Processing Record 29 of Set 14 | fairbanks
# Processing Record 30 of Set 14 | esperance
# Processing Record 31 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 14 | richards bay
# Processing Record 33 of Set 14 | vestmannaeyjar
# Processing Record 34 of Set 14 | comodoro rivadavia
# Processing Record 35 of Set 14 | samana
# Processing Record 36 of Set 14 | bathsheba
# Processing Record 37 of Set 14 | mingaora
# Processing Record 38 of Set 14 | atuona
# Processing Record 39 of Set 14 | liverpool
# Processing Record 40 of Set 14 | hermanus
# Processing Record 41 of Set 14 | snezhnogorsk
# Processing Record 42 of Set 14 | faanui
# Processing Record 43 of Set 14 | leningradskiy
# Processing Record 44 of Set 14 | chuy
# Processing Record 45 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 14 | bluff
# Processing Record 47 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 48 of Set 14 | newton
# Processing Record 49 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 50 of Set 14 | boca do acre
# Processing Record 1 of Set 15 | igarka
# Processing Record 2 of Set 15 | sao joao da barra
# Processing Record 3 of Set 15 | mizan teferi
# Processing Record 4 of Set 15 | mys shmidta
# City not found. Skipping...
# Processing Record 5 of Set 15 | ust-kalmanka
# Processing Record 6 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 7 of Set 15 | la ronge
# Processing Record 8 of Set 15 | awbari
# Processing Record 9 of Set 15 | sulangan
# Processing Record 10 of Set 15 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 15 | erzin
# Processing Record 12 of Set 15 | tengelic
# Processing Record 13 of Set 15 | inyonga
# Processing Record 14 of Set 15 | vanimo
# Processing Record 15 of Set 15 | arraial do cabo
# Processing Record 16 of Set 15 | minab
# Processing Record 17 of Set 15 | severo-kurilsk
# Processing Record 18 of Set 15 | dikson
# Processing Record 19 of Set 15 | pozo colorado
# Processing Record 20 of Set 15 | new norfolk
# Processing Record 21 of Set 15 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 15 | sao filipe
# Processing Record 23 of Set 15 | linping
# City not found. Skipping...
# Processing Record 24 of Set 15 | kuching
# Processing Record 25 of Set 15 | vila velha
# Processing Record 26 of Set 15 | arawa
# Processing Record 27 of Set 15 | egvekinot
# Processing Record 28 of Set 15 | ostrovnoy
# Processing Record 29 of Set 15 | cabo san lucas
# Processing Record 30 of Set 15 | port hardy
# Processing Record 31 of Set 15 | butaritari
# Processing Record 32 of Set 15 | abha
# Processing Record 33 of Set 15 | ulaangom
# Processing Record 34 of Set 15 | khatanga
# Processing Record 35 of Set 15 | ilam
# Processing Record 36 of Set 15 | mangan
# Processing Record 37 of Set 15 | saldanha
# Processing Record 38 of Set 15 | sabha
# Processing Record 39 of Set 15 | kaitangata
# Processing Record 40 of Set 15 | hami
# Processing Record 41 of Set 15 | baillif
# Processing Record 42 of Set 15 | araripina
# Processing Record 43 of Set 15 | saint anthony
# Processing Record 44 of Set 15 | san andres
# Processing Record 45 of Set 15 | caravelas
# Processing Record 46 of Set 15 | mareeba
# Processing Record 47 of Set 15 | salalah
# Processing Record 48 of Set 15 | ballina
# Processing Record 49 of Set 15 | roma
# Processing Record 50 of Set 15 | codrington
# Processing Record 1 of Set 16 | wucheng
# Processing Record 2 of Set 16 | bundaberg
# Processing Record 3 of Set 16 | pathanamthitta
# Processing Record 4 of Set 16 | north bend
# Processing Record 5 of Set 16 | gwadar
# Processing Record 6 of Set 16 | aripuana
# Processing Record 7 of Set 16 | saint-augustin
# Processing Record 8 of Set 16 | itacare
# Processing Record 9 of Set 16 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 16 | tuatapere
# Processing Record 11 of Set 16 | beringovskiy
# Processing Record 12 of Set 16 | coihaique
# Processing Record 13 of Set 16 | alofi
# Processing Record 14 of Set 16 | mar del plata
# Processing Record 15 of Set 16 | tasiilaq
# Processing Record 16 of Set 16 | quatre cocos
# Processing Record 17 of Set 16 | hasaki
# Processing Record 18 of Set 16 | lolua
# City not found. Skipping...
# Processing Record 19 of Set 16 | provideniya
# Processing Record 20 of Set 16 | bethel
# Processing Record 21 of Set 16 | yar-sale
# Processing Record 22 of Set 16 | anadyr
# Processing Record 23 of Set 16 | aklavik
# Processing Record 24 of Set 16 | port blair
# Processing Record 25 of Set 16 | pangnirtung
# Processing Record 26 of Set 16 | port elizabeth
# Processing Record 27 of Set 16 | airai
# Processing Record 28 of Set 16 | sapao
# City not found. Skipping...
# Processing Record 29 of Set 16 | cidreira
# Processing Record 30 of Set 16 | isangel
# Processing Record 31 of Set 16 | chancay
# Processing Record 32 of Set 16 | wa
# City not found. Skipping...
# Processing Record 33 of Set 16 | tefe
# Processing Record 34 of Set 16 | bilibino
# Processing Record 35 of Set 16 | arya
# City not found. Skipping...
# Processing Record 36 of Set 16 | tabas
# Processing Record 37 of Set 16 | guerrero negro
# Processing Record 38 of Set 16 | churapcha
# Processing Record 39 of Set 16 | talara
# Processing Record 40 of Set 16 | ndele
# City not found. Skipping...
# Processing Record 41 of Set 16 | pingliang
# Processing Record 42 of Set 16 | gurkovo
# Processing Record 43 of Set 16 | port alfred
# Processing Record 44 of Set 16 | koryukivka
# Processing Record 45 of Set 16 | santa maria chiquimula
# Processing Record 46 of Set 16 | presidencia roque saenz pena
# Processing Record 47 of Set 16 | santa fe
# Processing Record 48 of Set 16 | vung tau
# Processing Record 49 of Set 16 | bandarbeyla
# Processing Record 50 of Set 16 | victoria
# Processing Record 1 of Set 17 | saint-philippe
# Processing Record 2 of Set 17 | vestmanna
# Processing Record 3 of Set 17 | kyren
# Processing Record 4 of Set 17 | pierre
# Processing Record 5 of Set 17 | kasongo-lunda
# Processing Record 6 of Set 17 | japura
# Processing Record 7 of Set 17 | kutum
# Processing Record 8 of Set 17 | poltavka
# Processing Record 9 of Set 17 | korla
# City not found. Skipping...
# Processing Record 10 of Set 17 | acapulco
# Processing Record 11 of Set 17 | sorong
# Processing Record 12 of Set 17 | lorengau
# Processing Record 13 of Set 17 | port lincoln
# Processing Record 14 of Set 17 | kieta
# Processing Record 15 of Set 17 | areosa
# Processing Record 16 of Set 17 | longyearbyen
# Processing Record 17 of Set 17 | semarang
# Processing Record 18 of Set 17 | east london
# Processing Record 19 of Set 17 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 17 | soyo
# Processing Record 21 of Set 17 | gamba
# Processing Record 22 of Set 17 | krasnoselkup
# City not found. Skipping...
# Processing Record 23 of Set 17 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 17 | solovetskiy
# City not found. Skipping...
# Processing Record 25 of Set 17 | tateyama
# Processing Record 26 of Set 17 | jalu
# Processing Record 27 of Set 17 | yulara
# Processing Record 28 of Set 17 | kilindoni
# Processing Record 29 of Set 17 | mutare
# Processing Record 30 of Set 17 | muroto
# Processing Record 31 of Set 17 | hauterive
# Processing Record 32 of Set 17 | sept-iles
# Processing Record 33 of Set 17 | mogocha
# Processing Record 34 of Set 17 | phuket
# Processing Record 35 of Set 17 | fresnillo
# Processing Record 36 of Set 17 | mackay
# Processing Record 37 of Set 17 | lima
# Processing Record 38 of Set 17 | ariquemes
# Processing Record 39 of Set 17 | juifang
# City not found. Skipping...
# Processing Record 40 of Set 17 | hambantota
# Processing Record 41 of Set 17 | rundu
# Processing Record 42 of Set 17 | asht
# City not found. Skipping...
# Processing Record 43 of Set 17 | menongue
# Processing Record 44 of Set 17 | hoshiarpur
# Processing Record 45 of Set 17 | nizhneyansk
# City not found. Skipping...
# Processing Record 46 of Set 17 | olinda
# Processing Record 47 of Set 17 | rzhev
# Processing Record 48 of Set 17 | te anau
# Processing Record 49 of Set 17 | camana
# City not found. Skipping...
# Processing Record 50 of Set 17 | belushya guba
# City not found. Skipping...
# Processing Record 1 of Set 18 | kishi
# Processing Record 2 of Set 18 | gratia
# Processing Record 3 of Set 18 | tonantins
# Processing Record 4 of Set 18 | vila franca do campo
# Processing Record 5 of Set 18 | sukhoverkovo
# City not found. Skipping...
# Processing Record 6 of Set 18 | galesong
# Processing Record 7 of Set 18 | scottsburgh
# City not found. Skipping...
# Processing Record 8 of Set 18 | tecoanapa
# Processing Record 9 of Set 18 | adrar
# Processing Record 10 of Set 18 | chitipa
# Processing Record 11 of Set 18 | oranjemund
# Processing Record 12 of Set 18 | souillac
# Processing Record 13 of Set 18 | nantucket
# Processing Record 14 of Set 18 | hofn
# Processing Record 15 of Set 18 | quesnel
# Processing Record 16 of Set 18 | horodyshche
# Processing Record 17 of Set 18 | sangar
# Processing Record 18 of Set 18 | clyde river
# Processing Record 19 of Set 18 | shuyskoye
# Processing Record 20 of Set 18 | romanovo
# Processing Record 21 of Set 18 | andselv
# City not found. Skipping...
# Processing Record 22 of Set 18 | margate
# Processing Record 23 of Set 18 | tiarei
# Processing Record 24 of Set 18 | kijang
# Processing Record 25 of Set 18 | manambrag
# City not found. Skipping...
# Processing Record 26 of Set 18 | yantal
# Processing Record 27 of Set 18 | ojinaga
# Processing Record 28 of Set 18 | kisangani
# Processing Record 29 of Set 18 | ust-tsilma
# Processing Record 30 of Set 18 | pochutla
# Processing Record 31 of Set 18 | kruisfontein
# Processing Record 32 of Set 18 | mezen
# Processing Record 33 of Set 18 | maumere
# Processing Record 34 of Set 18 | grand river south east
# City not found. Skipping...
# Processing Record 35 of Set 18 | hithadhoo
# Processing Record 36 of Set 18 | gomel
# City not found. Skipping...
# Processing Record 37 of Set 18 | kirakira
# Processing Record 38 of Set 18 | marzuq
# Processing Record 39 of Set 18 | gat
# Processing Record 40 of Set 18 | guntakal
# Processing Record 41 of Set 18 | inirida
# Processing Record 42 of Set 18 | zelenogorskiy
# Processing Record 43 of Set 18 | torbay
# Processing Record 44 of Set 18 | sentyabrskiy
# City not found. Skipping...
# Processing Record 45 of Set 18 | northam
# Processing Record 46 of Set 18 | uige
# Processing Record 47 of Set 18 | ostersund
# Processing Record 48 of Set 18 | campo verde
# Processing Record 49 of Set 18 | dingle
# Processing Record 50 of Set 18 | aporawan
# City not found. Skipping...
# Processing Record 1 of Set 19 | grand gaube
# Processing Record 2 of Set 19 | bac lieu
# City not found. Skipping...
# Processing Record 3 of Set 19 | severnoye
# Processing Record 4 of Set 19 | juneau
# Processing Record 5 of Set 19 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 19 | arcachon
# Processing Record 7 of Set 19 | tumannyy
# City not found. Skipping...
# Processing Record 8 of Set 19 | the valley
# Processing Record 9 of Set 19 | gobabis
# Processing Record 10 of Set 19 | olga
# Processing Record 11 of Set 19 | almeirim
# Processing Record 12 of Set 19 | grindavik
# Processing Record 13 of Set 19 | padang
# Processing Record 14 of Set 19 | alta floresta
# Processing Record 15 of Set 19 | novopetrovskoye
# Processing Record 16 of Set 19 | lebu
# Processing Record 17 of Set 19 | ahipara
# Processing Record 18 of Set 19 | pevek
# Processing Record 19 of Set 19 | sao felix do xingu
# Processing Record 20 of Set 19 | manuk mangkaw
# Processing Record 21 of Set 19 | pisco
# Processing Record 22 of Set 19 | puerto madryn
# Processing Record 23 of Set 19 | srednekolymsk
# Processing Record 24 of Set 19 | saint-georges
# Processing Record 25 of Set 19 | kidal
# Processing Record 26 of Set 19 | nome
# Processing Record 27 of Set 19 | ormara
# Processing Record 28 of Set 19 | auki
# Processing Record 29 of Set 19 | chebenki
# Processing Record 30 of Set 19 | jabinyanah
# Processing Record 31 of Set 19 | tuy hoa
# Processing Record 32 of Set 19 | qasigiannguit
# Processing Record 33 of Set 19 | faro
# Processing Record 34 of Set 19 | nishihara
# Processing Record 35 of Set 19 | anzio
# Processing Record 36 of Set 19 | kapuskasing
# Processing Record 37 of Set 19 | ayan
# Processing Record 38 of Set 19 | tiksi
# Processing Record 39 of Set 19 | dalhousie
# Processing Record 40 of Set 19 | lavrentiya
# Processing Record 41 of Set 19 | ahuimanu
# Processing Record 42 of Set 19 | lufilufi
# Processing Record 43 of Set 19 | batagay
# Processing Record 44 of Set 19 | dakar
# Processing Record 45 of Set 19 | ascension
# City not found. Skipping...
# Processing Record 46 of Set 19 | abeche
# Processing Record 47 of Set 19 | shelburne
# Processing Record 48 of Set 19 | miles city
# Processing Record 49 of Set 19 | hamilton
# Processing Record 50 of Set 19 | isla mujeres
# Processing Record 1 of Set 20 | paranga
# Processing Record 2 of Set 20 | urengoy
# Processing Record 3 of Set 20 | merrill
# Processing Record 4 of Set 20 | tsogni
# Processing Record 5 of Set 20 | mahebourg
# Processing Record 6 of Set 20 | bridgetown
# Processing Record 7 of Set 20 | hay river
# Processing Record 8 of Set 20 | gardan diwal
# City not found. Skipping...
# Processing Record 9 of Set 20 | ngunguru
# Processing Record 10 of Set 20 | pitimbu
# Processing Record 11 of Set 20 | geraldton
# Processing Record 12 of Set 20 | acarau
# City not found. Skipping...
# Processing Record 13 of Set 20 | barbar
# City not found. Skipping...
# Processing Record 14 of Set 20 | carnarvon
# Processing Record 15 of Set 20 | lusambo
# Processing Record 16 of Set 20 | galgau
# City not found. Skipping...
# Processing Record 17 of Set 20 | abai
# Processing Record 18 of Set 20 | echirolles
# Processing Record 19 of Set 20 | mrirt
# City not found. Skipping...
# Processing Record 20 of Set 20 | sorvag
# City not found. Skipping...
# Processing Record 21 of Set 20 | miguel auza
# Processing Record 22 of Set 20 | mehamn
# Processing Record 23 of Set 20 | blagoveshchensk
# Processing Record 24 of Set 20 | bairiki
# City not found. Skipping...
# Processing Record 25 of Set 20 | bahar
# Processing Record 26 of Set 20 | nouadhibou
# Processing Record 27 of Set 20 | saint-pierre
# Processing Record 28 of Set 20 | saint george
# Processing Record 29 of Set 20 | chipinge
# Processing Record 30 of Set 20 | campo maior
# Processing Record 31 of Set 20 | tabou
# Processing Record 32 of Set 20 | norman wells
# Processing Record 33 of Set 20 | redcliffe
# Processing Record 34 of Set 20 | lasa
# Processing Record 35 of Set 20 | sataua
# City not found. Skipping...
# Processing Record 36 of Set 20 | mutoko
# Processing Record 37 of Set 20 | ouadda
# Processing Record 38 of Set 20 | matagami
# Processing Record 39 of Set 20 | banda aceh
# Processing Record 40 of Set 20 | dwarka
# Processing Record 41 of Set 20 | rognan
# Processing Record 42 of Set 20 | road town
# Processing Record 43 of Set 20 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 20 | belaya gora
# Processing Record 45 of Set 20 | port-gentil
# Processing Record 46 of Set 20 | kuopio
# Processing Record 47 of Set 20 | cabedelo
# Processing Record 48 of Set 20 | sitka
# Processing Record 49 of Set 20 | taltal
# Processing Record 50 of Set 20 | waipawa
# Processing Record 1 of Set 21 | wanning
# Processing Record 2 of Set 21 | ruatoria
# City not found. Skipping...
# Processing Record 3 of Set 21 | katha
# City not found. Skipping...
# Processing Record 4 of Set 21 | scarborough
# Processing Record 5 of Set 21 | taburi
# City not found. Skipping...
# Processing Record 6 of Set 21 | dunedin
# Processing Record 7 of Set 21 | hobyo
# Processing Record 8 of Set 21 | luderitz
# Processing Record 9 of Set 21 | kendari
# Processing Record 10 of Set 21 | indaiatuba
# Processing Record 11 of Set 21 | sola
# Processing Record 12 of Set 21 | mattru
# Processing Record 13 of Set 21 | trat
# Processing Record 14 of Set 21 | saskylakh
# Processing Record 15 of Set 21 | gornopravdinsk
# Processing Record 16 of Set 21 | labuhan
# Processing Record 17 of Set 21 | samusu
# City not found. Skipping...
# Processing Record 18 of Set 21 | gardez
# Processing Record 19 of Set 21 | zanjan
# Processing Record 20 of Set 21 | sabang
# Processing Record 21 of Set 21 | cuenca
# Processing Record 22 of Set 21 | maceio
# Processing Record 23 of Set 21 | chapais
# Processing Record 24 of Set 21 | putina
# Processing Record 25 of Set 21 | ginda
# Processing Record 26 of Set 21 | nosy varika
# Processing Record 27 of Set 21 | dimona
# Processing Record 28 of Set 21 | tilichiki
# Processing Record 29 of Set 21 | mocambique
# City not found. Skipping...
# Processing Record 30 of Set 21 | madang
# Processing Record 31 of Set 21 | lalin
# Processing Record 32 of Set 21 | lesosibirsk
# Processing Record 33 of Set 21 | beloha
# Processing Record 34 of Set 21 | yenagoa
# Processing Record 35 of Set 21 | trincomalee
# Processing Record 36 of Set 21 | qaqortoq
# Processing Record 37 of Set 21 | tokur
# Processing Record 38 of Set 21 | ejea de los caballeros
# Processing Record 39 of Set 21 | mount isa
# Processing Record 40 of Set 21 | corinto
# Processing Record 41 of Set 21 | pontal do parana
# Processing Record 42 of Set 21 | rincon
# Processing Record 43 of Set 21 | zrece
# Processing Record 44 of Set 21 | faya
# Processing Record 45 of Set 21 | alice springs
# Processing Record 46 of Set 21 | boulsa
# Processing Record 47 of Set 21 | manhattan
# Processing Record 48 of Set 21 | natal
# Processing Record 49 of Set 21 | kemijarvi
# City not found. Skipping...
# Processing Record 50 of Set 21 | samarai
# Processing Record 1 of Set 22 | winnemucca
# Processing Record 2 of Set 22 | skage
# City not found. Skipping...
# Processing Record 3 of Set 22 | rawson
# Processing Record 4 of Set 22 | yarqa
# Processing Record 5 of Set 22 | cockburn town
# Processing Record 6 of Set 22 | aleksandrovsk-sakhalinskiy
# Processing Record 7 of Set 22 | bonthe
# Processing Record 8 of Set 22 | ponta delgada
# Processing Record 9 of Set 22 | turukhansk
# Processing Record 10 of Set 22 | tsienyane
# City not found. Skipping...
# Processing Record 11 of Set 22 | dhidhdhoo
# Processing Record 12 of Set 22 | bom jesus
# Processing Record 13 of Set 22 | diamantino
# Processing Record 14 of Set 22 | santiago del estero
# Processing Record 15 of Set 22 | laguna
# Processing Record 16 of Set 22 | kavieng
# Processing Record 17 of Set 22 | bachaquero
# Processing Record 18 of Set 22 | flinders
# Processing Record 19 of Set 22 | titusville
# Processing Record 20 of Set 22 | narragansett
# Processing Record 21 of Set 22 | araouane
# Processing Record 22 of Set 22 | eureka
# Processing Record 23 of Set 22 | palora
# Processing Record 24 of Set 22 | spornoye
# Processing Record 25 of Set 22 | anuppur
# Processing Record 26 of Set 22 | am timan
# Processing Record 27 of Set 22 | ust-koksa
# Processing Record 28 of Set 22 | ancud
# Processing Record 29 of Set 22 | antofagasta
# Processing Record 30 of Set 22 | okhotsk
# Processing Record 31 of Set 22 | taraz
# Processing Record 32 of Set 22 | umm lajj
# Processing Record 33 of Set 22 | novovarshavka
# Processing Record 34 of Set 22 | mount gambier
# Processing Record 35 of Set 22 | esqueda
# Processing Record 36 of Set 22 | kaeo
# Processing Record 37 of Set 22 | westport
# Processing Record 38 of Set 22 | kawalu
# Processing Record 39 of Set 22 | krasnoarmeysk
# Processing Record 40 of Set 22 | meridian
# Processing Record 41 of Set 22 | tautira
# Processing Record 42 of Set 22 | key west
# Processing Record 43 of Set 22 | karratha
# Processing Record 44 of Set 22 | les cayes
# Processing Record 45 of Set 22 | asyut
# Processing Record 46 of Set 22 | dongsheng
# Processing Record 47 of Set 22 | avera
# Processing Record 48 of Set 22 | loukhi
# Processing Record 49 of Set 22 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 50 of Set 22 | robertsport
# Processing Record 1 of Set 23 | lagoa
# Processing Record 2 of Set 23 | fort nelson
# Processing Record 3 of Set 23 | kikwit
# Processing Record 4 of Set 23 | mweka
# Processing Record 5 of Set 23 | malwan
# City not found. Skipping...
# Processing Record 6 of Set 23 | qurayyat
# City not found. Skipping...
# Processing Record 7 of Set 23 | kautokeino
# Processing Record 8 of Set 23 | cap-haitien
# Processing Record 9 of Set 23 | belgaum
# Processing Record 10 of Set 23 | aloleng
# Processing Record 11 of Set 23 | ossora
# Processing Record 12 of Set 23 | namibe
# Processing Record 13 of Set 23 | truckee
# Processing Record 14 of Set 23 | paita
# Processing Record 15 of Set 23 | bousso
# City not found. Skipping...
# Processing Record 16 of Set 23 | marsa matruh
# Processing Record 17 of Set 23 | zachagansk
# City not found. Skipping...
# Processing Record 18 of Set 23 | yantai
# Processing Record 19 of Set 23 | jerome
# Processing Record 20 of Set 23 | warrnambool
# Processing Record 21 of Set 23 | fortuna
# Processing Record 22 of Set 23 | sao gabriel da cachoeira
# Processing Record 23 of Set 23 | wajid
# Processing Record 24 of Set 23 | maputo
# Processing Record 25 of Set 23 | vao
# Processing Record 26 of Set 23 | viedma
# Processing Record 27 of Set 23 | rawannawi
# City not found. Skipping...
# Processing Record 28 of Set 23 | stawell
# Processing Record 29 of Set 23 | guangzhou
# Processing Record 30 of Set 23 | bellevue
# Processing Record 31 of Set 23 | barra do garcas
# Processing Record 32 of Set 23 | solnechnyy
# Processing Record 33 of Set 23 | linhares
# Processing Record 34 of Set 23 | sumbawa
# City not found. Skipping...
# Processing Record 35 of Set 23 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 23 | bolungarvik
# City not found. Skipping...
# Processing Record 37 of Set 23 | ochakiv
# Processing Record 38 of Set 23 | naze
# Processing Record 39 of Set 23 | bayshore gardens
# Processing Record 40 of Set 23 | forestville
# Processing Record 41 of Set 23 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 42 of Set 23 | haines junction
# Processing Record 43 of Set 23 | corinth
# Processing Record 44 of Set 23 | klaksvik
# Processing Record 45 of Set 23 | havre-saint-pierre
# Processing Record 46 of Set 23 | suluq
# Processing Record 47 of Set 23 | kotma
# Processing Record 48 of Set 23 | yumen
# Processing Record 49 of Set 23 | trelew
# Processing Record 50 of Set 23 | port macquarie
# Processing Record 1 of Set 24 | mastic beach
# Processing Record 2 of Set 24 | campbellsville
# Processing Record 3 of Set 24 | esperantina
# Processing Record 4 of Set 24 | labutta
# City not found. Skipping...
# Processing Record 5 of Set 24 | cedar city
# Processing Record 6 of Set 24 | praia
# Processing Record 7 of Set 24 | xinye
# Processing Record 8 of Set 24 | denpasar
# Processing Record 9 of Set 24 | umba
# Processing Record 10 of Set 24 | whitley bay
# Processing Record 11 of Set 24 | belyy yar
# Processing Record 12 of Set 24 | ardatov
# Processing Record 13 of Set 24 | huarmey
# Processing Record 14 of Set 24 | bilma
# Processing Record 15 of Set 24 | muros
# Processing Record 16 of Set 24 | tashtyp
# Processing Record 17 of Set 24 | burnie
# Processing Record 18 of Set 24 | punta alta
# Processing Record 19 of Set 24 | moba
# Processing Record 20 of Set 24 | maskinonge
# Processing Record 21 of Set 24 | rongcheng
# Processing Record 22 of Set 24 | marrakesh
# Processing Record 23 of Set 24 | beverley
# Processing Record 24 of Set 24 | san cristobal
# Processing Record 25 of Set 24 | satitoa
# City not found. Skipping...
# Processing Record 26 of Set 24 | erenhot
# Processing Record 27 of Set 24 | plettenberg bay
# Processing Record 28 of Set 24 | santa helena de goias
# Processing Record 29 of Set 24 | broome
# Processing Record 30 of Set 24 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 31 of Set 24 | moerai
# Processing Record 32 of Set 24 | pacific grove
# Processing Record 33 of Set 24 | krasnogorsk
# Processing Record 34 of Set 24 | oranjestad
# Processing Record 35 of Set 24 | laramie
# Processing Record 36 of Set 24 | pringsewu
# Processing Record 37 of Set 24 | bayangol
# Processing Record 38 of Set 24 | saleaula
# City not found. Skipping...
# Processing Record 39 of Set 24 | kattivakkam
# Processing Record 40 of Set 24 | arcoverde
# Processing Record 41 of Set 24 | lixourion
# Processing Record 42 of Set 24 | miyang
# Processing Record 43 of Set 24 | arua
# Processing Record 44 of Set 24 | praia da vitoria
# Processing Record 45 of Set 24 | tirumullaivasal
# Processing Record 46 of Set 24 | port-cartier
# Processing Record 47 of Set 24 | sarankhola
# Processing Record 48 of Set 24 | lloydminster
# Processing Record 49 of Set 24 | hirara
# Processing Record 50 of Set 24 | sur
# Processing Record 1 of Set 25 | kribi
# Processing Record 2 of Set 25 | bobcaygeon
# Processing Record 3 of Set 25 | talcahuano
# Processing Record 4 of Set 25 | cao bang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Constitucion  23.99 -104.67     51.80       100          90        9.17
# 1            Hilo  19.71 -155.08     84.20        62          20        9.17
# 2         Mataura -46.19  168.86     63.00        52         100       23.00
# 3  Ribeira Grande  38.52  -28.70     62.60        90          40        7.92
# 4       Busselton -33.64  115.35     71.01        34           0       11.01
# 5    Komsomolskiy  67.55   63.78     -7.10        88           0        5.46
# 6       Cape Town -33.93   18.42     64.99        77          20       17.22
# 7           Kapaa  22.08 -159.32     84.20        74          90        3.47
# 8    Puerto Ayora  -0.74  -90.35     78.80        61          20        9.17
# 9         Cayenne   4.94  -52.33     78.80        88          14        5.35
#
#   Country                 Date
# 0      MX  2019-11-12 23:47:00
# 1      US  2019-11-12 23:47:01
# 2      NZ  2019-11-12 23:47:01
# 3      PT  2019-11-12 23:47:01
# 4      AU  2019-11-12 23:45:45
# 5      RU  2019-11-12 23:47:02
# 6      ZA  2019-11-12 23:46:07
# 7      US  2019-11-12 23:47:02
# 8      EC  2019-11-12 23:47:02
# 9      GF  2019-11-12 23:39:40

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_challenge.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_Challenge")
